# %%
# credit card Data Set

# %%
# impoting all the dependencies.
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# reading the data Set 
credit_card_df=pd.read_csv('D:\\Data Sets\\creditcard.csv')

# %%
credit_card_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# # After viewing the data realised that data is already standardize

# %%
credit_card_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#checking the missing values 
credit_card_df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#checking the legit transaction and fraudulant transaction 
credit_card_df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# # This data is Highly Unballanced
# ## where,
# ## 0 represents normal transaction transactions
# ## 1 represents fraudulant transaction

# %%
# seprating two data sets for analysis 
legit = credit_card_df[credit_card_df.Class== 0]
fraud = credit_card_df[credit_card_df.Class== 1]

# %%
print (legit.shape)
print (fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# comparing values for both the transactions 
credit_card_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ##  As we got to know the data set is unballanced data set we are going to take equal sample 492 random normal transaction and 492 fradulant transaction in our sample which will be good sample data set for this data set

# %%
#Normal transactions
legit_sample= legit.sample(n=492)

# %%
# concantinate two data sets

# %%
new_data= pd.concat([fraud,legit_sample],axis =0)

# %%
# New Concantinate data set where we have equal 
new_data.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_data['Class'].value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92541.900407 -0.108021  0.072542  0.169939 -0.016790  0.049086
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.068572  0.002529 -0.023509 -0.067396  ...  0.013801  0.004725
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.029344 -0.016916  0.045595 -0.006410 -0.023371 -0.014292 -0.000787
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       86.819085
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# spliting the feautures and  targets

# %%
x=new_data.drop(columns='Class',axis=1)
y=new_data['Class']

# %%
print (x.head())
print (y.head())
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V20       V21       V22  \
# 541  -2.537387  1.391657 -2.770089  ...  0.126911  0.517232 -0.035049
# 623   0.325574 -0.067794 -0.270953  ...  2.102339  0.661696  0.435477
# 4920  0.562320 -0.399147 -0.238253  ... -0.430022 -0.294166 -0.932391
# 6108 -3.496197 -0.248778 -0.247768  ... -0.171608  0.573574  0.176968
# 6329  1.713445 -0.496358 -1.282858  ...  0.009061 -0.379068 -0.704181
#
#            V23       V24       V25       V26       V27       V28  Amount
# ...

# %%
# spliting the data into train data and test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, stratify=y, random_state=2)

# %%
print (x.shape, x_train.shape ,x_test.shape)
# Out:
# (984, 30) (738, 30) (246, 30)

# %%
# Modelling

# %%
# Logistic regresion

# %%
model = LogisticRegression()

# %%
# training the logistic regression model with train data

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# checking accuracy on train data 
x_train_predictions = model.predict(x_train)
training_data_accuracy=accuracy_score(x_train_predictions,y_train)

# %%
print ("traing data accuracy: ",training_data_accuracy)
# Out:
# traing data accuracy:  0.9444444444444444

# %%
# checking accuracy on test data 
x_test_predictions = model.predict(x_test)
testing_data_accuracy=accuracy_score(x_test_predictions,y_test)

# %%
print ("test data accuracy: ",testing_data_accuracy)
# Out:
# test data accuracy:  0.9227642276422764

# %% [markdown]
# # Insights
# * The provided accuracy values offer valuable insights into the performance of the trained model. With a training data accuracy of approximately 94.44 %,  it's evident that the model has effectively captured the underlying patterns and features present in the training dataset. This high accuracy suggests that the model has learned to make accurate predictions on familiar data. Moving to the testing data accuracy, which stands at around 92.28%, we can observe that the model's generalization to unseen data is commendable. While the testing accuracy is slightly lower than the training accuracy, this difference is not drastic, indicating a balanced level of generalization. This balance between training and testing accuracies suggests that the model is not excessively overfitting or underfitting the data. To further enhance performance, explorations into hyperparameter tuning and potential model architecture adjustments could be considered. Additionally, considering alternative evaluation metrics beyond accuracy, such as precision, recall, and F1-score, would provide a more comprehensive understanding of the model's capabilities. In a real-world context, these insights will be crucial in determining the suitability of the model for its intended application and making informed decisions regarding potential enhancements.
